# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset from same folder as the notebook
# Use a simple relative path so the file can be loaded with:
# df = pd.read_csv("telco_churn.csv")

df = pd.read_csv("telco_churn.csv")

# Preview
print(f"Loaded from current folder, shape: {df.shape}")
print("First 5 rows:")
print(df.head())
